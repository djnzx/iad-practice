# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# generation of synthetic dataset
N = 100
a = 1
b = 3

x = np.random.uniform(0, 5, N)
noise = np.random.normal(0, .5, N)
y = a * x + b + noise

plt.grid()
plt.scatter(x, y, marker = '.', color = 'r')

# %%
X = x.reshape(-1, 1)

# %%
x # 1d array
# Out:
# array([1.97963383, 2.61492852, 3.02099297, 1.28856257, 4.87321527,
#        3.3549245 , 2.13356209, 0.29388757, 2.46476583, 4.63537033,
#        4.67346859, 3.07812765, 4.78996112, 2.37603132, 2.15915493,
#        1.60863967, 4.76625265, 2.72127814, 3.0673972 , 3.67570081,
#        0.4111209 , 2.9071117 , 4.34976315, 1.61421496, 0.60046176,
#        3.66296731, 4.42661368, 4.41208807, 1.08474479, 2.91302754,
#        1.83368588, 2.54224675, 4.02461651, 2.82652716, 2.48237873,
#        0.68249408, 0.60528618, 0.00666978, 2.80970626, 0.37839499,
#        4.66423733, 0.67307376, 3.61195773, 2.25378678, 1.90327154,
#        3.8585098 , 2.66018892, 0.42125655, 0.99161589, 3.78525306,
#        2.40705312, 3.80049175, 2.20587735, 3.72368732, 1.89251397,
#        3.46577449, 1.25518405, 1.87973737, 4.44105275, 0.06670916,
#        1.72238632, 2.4168661 , 2.50350837, 4.86624663, 1.48813102,
#        3.56491176, 1.81538378, 1.81330334, 2.40686018, 4.15316213,
#        1.52336638, 4.99715122, 1.04461996, 1.28170952, 2.56558544,
#        2.83287547, 4.34415679, 1.60804516, 3.27872168, 0.39466877,
#        4.48438841, 3.52105112, 2.29562551, 2.88883844, 1.46477254,
#        2.87867683, 4.95806489, 2.86256837, 3.27566008, 2.13531693,
#        1.12710499, 0.44739342, 2.34206535, 4.01358461, 4.81236402,
#        0.71502637, 0.05155309, 1.47974695, 3.483564  , 0.02844148])

# %%
X # array where each row is an array to
# Out:
# array([[1.97963383],
#        [2.61492852],
#        [3.02099297],
#        [1.28856257],
#        [4.87321527],
#        [3.3549245 ],
#        [2.13356209],
#        [0.29388757],
#        [2.46476583],
#        [4.63537033],
#        [4.67346859],
#        [3.07812765],
#        [4.78996112],
#        [2.37603132],
#        [2.15915493],
#        [1.60863967],
#        [4.76625265],
#        [2.72127814],
#        [3.0673972 ],
#        [3.67570081],
#        [0.4111209 ],
#        [2.9071117 ],
#        [4.34976315],
#        [1.61421496],
#        [0.60046176],
#        [3.66296731],
#        [4.42661368],
#        [4.41208807],
#        [1.08474479],
#        [2.91302754],
#        [1.83368588],
#        [2.54224675],
#        [4.02461651],
#        [2.82652716],
#        [2.48237873],
#        [0.68249408],
#        [0.60528618],
#        [0.00666978],
#        [2.80970626],
#        [0.37839499],
#        [4.66423733],
#        [0.67307376],
#        [3.61195773],
#        [2.25378678],
#        [1.90327154],
#        [3.8585098 ],
#        [2.66018892],
#        [0.42125655],
#        [0.99161589],
#        [3.78525306],
#        [2.40705312],
#        [3.80049175],
#        [2.20587735],
#        [3.72368732],
#        [1.89251397],
#        [3.46577449],
#        [1.25518405],
#        [1.87973737],
#        [4.44105275],
#        [0.06670916],
#        [1.72238632],
#        [2.4168661 ],
#        [2.50350837],
#        [4.86624663],
#        [1.48813102],
#        [3.56491176],
#        [1.81538378],
#        [1.81330334],
#        [2.40686018],
#        [4.15316213],
#        [1.52336638],
#        [4.99715122],
#        [1.04461996],
#        [1.28170952],
#        [2.56558544],
#        [2.83287547],
#        [4.34415679],
#        [1.60804516],
#        [3.27872168],
#        [0.39466877],
#        [4.48438841],
#        [3.52105112],
#        [2.29562551],
#        [2.88883844],
#        [1.46477254],
#        [2.87867683],
#        [4.95806489],
#        [2.86256837],
#        [3.27566008],
#        [2.13531693],
#        [1.12710499],
#        [0.44739342],
#        [2.34206535],
#        [4.01358461],
#        [4.81236402],
#        [0.71502637],
#        [0.05155309],
#        [1.47974695],
#        [3.483564  ],
#        [0.02844148]])

# %%
# a * x + b = y

model = LinearRegression()
model.fit(X, y)
model
# Out:
# LinearRegression()

# %%
a_found = model.coef_[0]
b_found = model.intercept_

# %%
a_found
# Out:
# np.float64(1.0073692393631353)

# %%
b_found
# Out:
# np.float64(2.8934710148027087)
